# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
new = "/home/sauer_julian/code/MarieKatha/berlin-property-intelligence/raw_data/new_construction.csv"
rentals = "/home/sauer_julian/code/MarieKatha/berlin-property-intelligence/raw_data/rentals.csv"
bestand = "/home/sauer_julian/code/MarieKatha/berlin-property-intelligence/raw_data/secondary_sales.csv"

df_new = pd.read_csv(new)
df_rental = pd.read_csv(rentals)
df_bestand = pd.read_csv(bestand)

# %%
pd.set_option('display.max_columns', None)

# %%
df_new.head()
# Out:
#         id date_listed project_id          project_name       developer  \
# 0  N000001  2024-05-20     NC0120           Kiez Moabit  STADT UND LAND
# 1  N000002  2024-02-06     NC0051  Platz Charlottenburg          GAGFAH
# 2  N000003  2022-11-10     NC0066     Höfe Lichterfelde     Adler Group
# 3  N000004  2023-09-19     NC0067  Hofgarten Tiergarten       Berlinovo
# 4  N000005  2024-08-26     NC0115     Living Mariendorf       Berlinovo
#
#          ortsteil                      bezirk       lat       lon  \
# 0          Moabit                       Mitte  52.52846  13.34076
# 1  Charlottenburg  Charlottenburg-Wilmersdorf  52.51224  13.30218
# 2    Lichterfelde         Steglitz-Zehlendorf  52.42957  13.30744
# 3      Tiergarten                       Mitte  52.51410  13.35763
# 4      Mariendorf        Tempelhof-Schöneberg  52.44131  13.39152
#
#   property_type  rooms  area_m2  floor  total_floors energy_class  \
# ...

# %%
df_new.columns
# Out:
# Index(['id', 'date_listed', 'project_id', 'project_name', 'developer',
#        'ortsteil', 'bezirk', 'lat', 'lon', 'property_type', 'rooms', 'area_m2',
#        'floor', 'total_floors', 'energy_class', 'completion_year',
#        'total_project_units', 'possession_status', 'payment_plan', 'has_lift',
#        'has_balcony', 'has_parking', 'transit_station', 'transit_line',
#        'transit_distance_min', 'to_brandenburg_gate_km', 'price_eur',
#        'price_per_m2_eur', 'price_usd', 'price_per_m2_usd',
#        'mortgage_rate_at_listing'],
#       dtype='object')

# %%
df_rental.head()
# Out:
#         id date_listed     ortsteil               bezirk kiez_premium  \
# 0  R000001  2023-12-18    Adlershof     Treptow-Köpenick       medium
# 1  R000002  2021-06-07     Lankwitz  Steglitz-Zehlendorf       medium
# 2  R000003  2022-08-19        Britz             Neukölln          low
# 3  R000004  2025-12-29  Hellersdorf  Marzahn-Hellersdorf          low
# 4  R000005  2022-07-18   Wartenberg          Lichtenberg          low
#
#         lat       lon property_type  rooms  area_m2  floor  total_floors  \
# 0  52.44391  13.53835        2_room      2     55.1      0             3
# 1  52.44035  13.33848        4_room      4    106.6      5             6
# 2  52.44825  13.45215        3_room      3    102.5      3             5
# 3  52.53063  13.62405        3_room      3     90.5      0             5
# 4  52.58212  13.50497        2_room      2     55.6      5             6
#
#          building_era energy_class      position     condition  has_lift  \
# ...

# %%
df_rental.columns
# Out:
# Index(['id', 'date_listed', 'ortsteil', 'bezirk', 'kiez_premium', 'lat', 'lon',
#        'property_type', 'rooms', 'area_m2', 'floor', 'total_floors',
#        'building_era', 'energy_class', 'position', 'condition', 'has_lift',
#        'has_balcony', 'furnished', 'transit_station', 'transit_line',
#        'transit_distance_min', 'to_brandenburg_gate_km',
#        'kaltmiete_eur_monthly', 'nebenkosten_eur_monthly',
#        'warmmiete_eur_monthly', 'rent_per_m2_kalt_eur',
#        'rent_includes_warmmiete', 'kaution_months',
#        'warmmiete_eur_monthly_usd'],
#       dtype='object')

# %%
df_bestand.head()
# Out:
#         id date_listed        ortsteil                    bezirk kiez_premium  \
# 0  S000001  2024-11-23       Kreuzberg  Friedrichshain-Kreuzberg         high
# 1  S000002  2025-06-06           Gatow                   Spandau       medium
# 2  S000003  2021-03-13  Köpenick (Ort)          Treptow-Köpenick       medium
# 3  S000004  2024-12-08     Mitte (Ort)                     Mitte         high
# 4  S000005  2021-05-10        Wittenau             Reinickendorf          low
#
#         lat       lon property_type  rooms  area_m2  floor  total_floors  \
# 0  52.50656  13.40768        2_room      2     69.0      1             6
# 1  52.47856  13.17688        3_room      3     82.0      4             5
# 2  52.45023  13.57624        1_room      1     28.3      2             4
# 3  52.52427  13.41293        4_room      4    108.0      3             5
# 4  52.59374  13.31938        2_room      2     44.7      4             4
#
# ...

# %%
df_bestand.columns
# Out:
# Index(['id', 'date_listed', 'ortsteil', 'bezirk', 'kiez_premium', 'lat', 'lon',
#        'property_type', 'rooms', 'area_m2', 'floor', 'total_floors',
#        'year_built', 'building_era', 'energy_class', 'position', 'condition',
#        'has_lift', 'has_balcony', 'has_cellar', 'has_parking',
#        'transit_station', 'transit_line', 'transit_distance_min',
#        'transit_distance_type', 'to_brandenburg_gate_km', 'price_eur',
#        'price_per_m2_eur', 'price_usd', 'price_per_m2_usd',
#        'mortgage_rate_at_listing'],
#       dtype='object')
